# %%
import requests
import json

# Configuration
URL = "https://unpalpablely-vibronic-leonore.ngrok-free.dev/api/v1/chat/completions"
API_KEY = "YOUR_API_KEY_HERE"  
MODEL_NAME = "qwen/qwen3-30b-a3b-2507"

def envoyer_requete(prompt):
    headers = {
        "Content-Type": "application/json",
        "Authorization": f"Bearer {API_KEY}",
    }

    data = {
        "model": MODEL_NAME,
        "messages": [
            {"role": "user", "content": prompt}
        ],
        # Désactive le streaming pour avoir une réponse d'un bloc
        "stream": False 
    }

    try:
        response = requests.post(URL, headers=headers, data=json.dumps(data))
        response.raise_for_status() # Vérifie si la requête a réussi (code 200)
        
        resultat = response.json()
        return resultat['choices'][0]['message']['content']
    
    except requests.exceptions.RequestException as e:
        return f"Erreur de connexion : {e}"
    except KeyError:
        return "Erreur : Format de réponse inattendu."

# Test
if __name__ == "__main__":
    reponse = envoyer_requete("Pourquoi le ciel est bleu ?")
    print(reponse)
# Out:
# Le ciel est bleu à cause d’un phénomène appelé **diffusion de Rayleigh**.
#
# Voici comment ça fonctionne :
#
# 1. **La lumière du Soleil** est composée de toutes les couleurs du spectre visible (rouge, orange, jaune, vert, bleu, indigo, violet). Elle semble blanche parce qu’elle contient toutes ces couleurs mélangées.
#
# 2. Quand cette lumière pénètre dans l’atmosphère terrestre, elle entre en collision avec les molécules d’air (azote, oxygène) et les petites particules présentes dans l’air.
#
# 3. Ces molécules diffusent la lumière dans toutes les directions. Mais **la diffusion dépend de la longueur d’onde de la lumière** :
#    - Les courtes longueurs d’onde (comme le bleu et le violet) sont diffusées **beaucoup plus** que les longues (comme le rouge ou l’orange).
#    - Le bleu a une longueur d’onde plus courte que le rouge, donc il est diffusé environ **10 fois plus** que le rouge.
#
# 4. Même si le violet est encore plus diffusé que le bleu, notre œil est plus sensible au bleu, et le Soleil émet plus de lumière bleue que violette. C’est pourquoi **on voit le ciel bleu**.
#
# 👉 En résumé :
# Le ciel est bleu parce que les molécules de l’atmosphère diffusent davantage la lumière bleue (courte longueur d’onde) que les autres couleurs, la rendant visible de n’importe où dans le ciel.
#
# 💡 Astuce : Le ciel devient rouge ou orange au lever et coucher du soleil, car la lumière solaire doit traverser une plus grande épaisseur d’atmosphère, ce qui fait que la lumière bleue est diffusée loin de notre regard, laissant passer surtout les longues longueurs d’onde (rouge, orange).
